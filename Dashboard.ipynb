# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('C:\MLProject\FHV_Data_NYC.csv')
df = df.rename(columns = {'Base Name': 'Base_Name','Total Dispatched Trips':'Total_Dispatched_Trips','Total Dispatched Shared Trips':'Total_Dispatched_Shared_Trips','Unique Dispatched Vehicles':'Unique_Dispatched_Vehicles','Month Name':'Month_Name'})


df['Total_Dispatched_Trips'] = df['Total_Dispatched_Trips'].astype(str).replace(',','', regex=True).astype(int)
df['Unique_Dispatched_Vehicles'] = df['Total_Dispatched_Trips'].astype(str).replace(',','', regex=True).astype(int)
df['Total_Dispatched_Shared_Trips'] = df['Total_Dispatched_Trips'].astype(str).replace(',','', regex=True).astype(int)

df_2015 = df[df.Year == 2015]
ride_sharing_2015 = df_2015[df_2015.Total_Dispatched_Shared_Trips > 0]

rs_2015_u = ride_sharing_2015[ride_sharing_2015.Base_Name == 'UBER']
total_trips_2015_u = rs_2015_u['Total_Dispatched_Trips'].sum()
rs_2015_v = ride_sharing_2015[ride_sharing_2015.Base_Name == 'VIA']
total_trips_2015_v = rs_2015_v['Total_Dispatched_Trips'].sum()
rs_2015_l = ride_sharing_2015[ride_sharing_2015.Base_Name == 'LYFT']
total_trips_2015_l = rs_2015_l['Total_Dispatched_Trips'].sum()
rs_2015_o = ride_sharing_2015[~ride_sharing_2015.Base_Name.isin(['UBER','LYFT','VIA']) & ride_sharing_2015.Total_Dispatched_Shared_Trips > 0]
total_trips_2015_o = rs_2015_o['Total_Dispatched_Trips'].sum()
by_month_rs = pd.concat([rs_2015_u])
by_month_2015 = rs_2015_o.groupby('Month_Name')
by_month_2015 = by_month_2015['Total_Dispatched_Trips'].sum().reset_index()



sub = by_month_rs[['Month','Total_Dispatched_Trips']]

print(by_month_2015)

fig, ax = plt.subplots(figsize=(15, 15))
ax.set_xlim([1,12])
ax.set_ylim([0,5000000])
ax.plot(rs_2015_u['Month'],rs_2015_u['Total_Dispatched_Trips'], label='UBER')
ax.plot(rs_2015_v['Month'],rs_2015_v['Total_Dispatched_Trips'], label='VIA')
ax.plot(rs_2015_l['Month'],rs_2015_l['Total_Dispatched_Trips'], label='LYFT')
ax.plot(by_month_2015['Month_Name'], by_month_2015['Total_Dispatched_Trips'], label='Other')
ax.xaxis.set_ticks(np.arange(1, 13, 1))
ax.yaxis.set_ticks(np.arange(0,5000000, 250000))
ax.legend( ('UBER', 'VIA','LYFT','OTHER'), loc='upper left', shadow=True)
#ax.ticklabel_format(style='plain') 
ax.set_title('Dispatched Rides in 2015', 
             fontsize = 14)
ax.set_xlabel('Month')
ax.set_ylabel('Dispatched Rides')


df_2016 = df[df.Year == 2016]
ride_sharing_2016 = df_2016[df_2016.Total_Dispatched_Shared_Trips > 0]
total_ride_sharing_trips_2016 = sum(ride_sharing_2016.Total_Dispatched_Trips)
rs_2016_u = ride_sharing_2016[ride_sharing_2016.Base_Name == 'UBER']
total_trips_2016_u = rs_2016_u['Total_Dispatched_Trips'].sum()
rs_2016_v = ride_sharing_2016[ride_sharing_2016.Base_Name == 'VIA']
total_trips_2016_v = rs_2016_v['Total_Dispatched_Trips'].sum()
rs_2016_l = ride_sharing_2016[ride_sharing_2016.Base_Name == 'LYFT']
total_trips_2016_l = rs_2016_l['Total_Dispatched_Trips'].sum()
rs_2016_o = ride_sharing_2016[~ride_sharing_2016.Base_Name.isin(['UBER','LYFT','VIA']) & ride_sharing_2016.Total_Dispatched_Shared_Trips > 0]
total_trips_2016_o = rs_2016_o['Total_Dispatched_Trips'].sum()
by_month_2016 = rs_2016_o.groupby('Month_Name')
by_month_2016 = by_month_2016['Total_Dispatched_Trips'].sum().reset_index()



df_2017 = df[df.Year == 2017]
ride_sharing_2017 = df_2017[df_2017.Total_Dispatched_Shared_Trips > 0]
total_ride_sharing_trips_2017 = sum(ride_sharing_2017.Total_Dispatched_Trips)
rs_2017_u = ride_sharing_2017[ride_sharing_2017.Base_Name == 'UBER']
total_trips_2017_u = rs_2017_u['Total_Dispatched_Trips'].sum()
rs_2017_v = ride_sharing_2017[ride_sharing_2017.Base_Name == 'VIA']
total_trips_2017_v = rs_2017_v['Total_Dispatched_Trips'].sum()
rs_2017_l = ride_sharing_2017[ride_sharing_2017.Base_Name == 'LYFT']
total_trips_2017_l = rs_2017_l['Total_Dispatched_Trips'].sum()
rs_2017_o = ride_sharing_2017[~ride_sharing_2017.Base_Name.isin(['UBER','LYFT','VIA']) & ride_sharing_2017.Total_Dispatched_Shared_Trips > 0]
total_trips_2017_o = rs_2017_o['Total_Dispatched_Trips'].sum()
by_month_2017 = rs_2017_o.groupby('Month_Name')
by_month_2017 = by_month_2017['Total_Dispatched_Trips'].sum().reset_index()



df_2018 = df[df.Year == 2018]
ride_sharing_2018 = df_2018[df_2018.Total_Dispatched_Shared_Trips > 0]
total_ride_sharing_trips_2018 = sum(ride_sharing_2018.Total_Dispatched_Trips)
rs_2018_u = ride_sharing_2018[ride_sharing_2018.Base_Name == 'UBER']
total_trips_2018_u = rs_2018_u['Total_Dispatched_Trips'].sum()
rs_2018_v = ride_sharing_2018[ride_sharing_2018.Base_Name == 'VIA']
total_trips_2018_v = rs_2018_v['Total_Dispatched_Trips'].sum()
rs_2018_l = ride_sharing_2018[ride_sharing_2018.Base_Name == 'LYFT']
total_trips_2018_l = rs_2018_l['Total_Dispatched_Trips'].sum()
rs_2018_o = ride_sharing_2018[~ride_sharing_2018.Base_Name.isin(['UBER','LYFT','VIA']) & ride_sharing_2018.Total_Dispatched_Shared_Trips > 0]
total_trips_2018_o = rs_2018_o['Total_Dispatched_Trips'].sum()
by_month_2018 = ride_sharing_2018.groupby('Month')['Total_Dispatched_Trips'].sum()
by_month_2018 = rs_2018_o.groupby('Month_Name')['Total_Dispatched_Trips'].sum()
by_month_2018 = rs_2018_o.groupby('Month_Name')
by_month_2018 = by_month_2018['Total_Dispatched_Trips'].sum().reset_index()



df_2019 = df[df.Year == 2019]
ride_sharing_2019 = df_2019[df_2019.Total_Dispatched_Shared_Trips > 0]
total_ride_sharing_trips_2019 = sum(ride_sharing_2019.Total_Dispatched_Trips)
rs_2019_u = ride_sharing_2019[ride_sharing_2019.Base_Name == 'UBER']
total_trips_2019_u = rs_2019_u['Total_Dispatched_Trips'].sum()
rs_2019_v = ride_sharing_2019[ride_sharing_2019.Base_Name == 'VIA']
total_trips_2019_v = rs_2019_v['Total_Dispatched_Trips'].sum()
rs_2019_l = ride_sharing_2019[ride_sharing_2019.Base_Name == 'LYFT']
total_trips_2019_l = rs_2019_l['Total_Dispatched_Trips'].sum()
rs_2019_o = ride_sharing_2019[~ride_sharing_2019.Base_Name.isin(['UBER','LYFT','VIA']) & ride_sharing_2019.Total_Dispatched_Shared_Trips > 0]
total_trips_2019_o = rs_2019_o['Total_Dispatched_Trips'].sum()
by_month_2019 = rs_2019_o.groupby('Month_Name')['Total_Dispatched_Trips'].sum()
by_month_2019 = rs_2019_o.groupby('Month_Name')
by_month_2019 = by_month_2019['Total_Dispatched_Trips'].sum().reset_index()


df_2020 = df[df.Year == 2020]
ride_sharing_2020 = df_2020[df_2020.Total_Dispatched_Shared_Trips > 0]
total_ride_sharing_trips_2020 = sum(ride_sharing_2020.Total_Dispatched_Trips)
rs_2020_u = ride_sharing_2020[ride_sharing_2020.Base_Name == 'UBER']
total_trips_2020_u = rs_2020_u['Total_Dispatched_Trips'].sum()
rs_2020_v = ride_sharing_2020[ride_sharing_2020.Base_Name == 'VIA']
total_trips_2020_v = rs_2020_v['Total_Dispatched_Trips'].sum()
rs_2020_l = ride_sharing_2020[ride_sharing_2020.Base_Name == 'LYFT']
total_trips_2020_l = rs_2020_l['Total_Dispatched_Trips'].sum()
rs_2020_o = ride_sharing_2020[~ride_sharing_2020.Base_Name.isin(['UBER','LYFT','VIA']) & ride_sharing_2020.Total_Dispatched_Shared_Trips > 0]
total_trips_2020_o = rs_2020_o['Total_Dispatched_Trips'].sum()
by_month_2020 = ride_sharing_2020.groupby('Month')['Total_Dispatched_Trips'].sum()
by_month_2020 = rs_2020_o.groupby('Month_Name')['Total_Dispatched_Trips'].sum()
by_month_2020 = rs_2020_o.groupby('Month_Name')
by_month_2020 = by_month_2020['Total_Dispatched_Trips'].sum().reset_index()





#ride_sharing_trips_by_year = {'Year':[2015, 2016, 2017, 2018, 2019, 2020] ,'Total_Trips':[total_ride_sharing_trips_2015,total_ride_sharing_trips_2016,total_ride_sharing_trips_2017,total_ride_sharing_trips_2018,total_ride_sharing_trips_2019,total_ride_sharing_trips_2020]}
#df_ride_sharing_trips_by_year = pd.DataFrame(ride_sharing_trips_by_year)


#plt.plot(by_month_2015, label='2015')
#plt.plot(by_month_2016, label='2016')
#plt.plot(by_month_2017, label='2017')
#plt.plot(by_month_2018, label='2018')
#plt.plot(by_month_2019, label='2019')
#plt.plot(by_month_2020, label='2020')
#print(by_month_2015)
#print(by_month_2016)
#print(by_month_2017)
#print(by_month_2018)
#print(by_month_2019)
#print(by_month_2020)
# Out:
#    Month_Name  Total_Dispatched_Trips
# 0       April                  716394
# 1      August                  548911
# 2    December                 1678867
# 3    February                  445020
# 4     January                  515876
# 5        July                  410502
# 6        June                  611583
# 7       March                  495068
# 8         May                  593071
# 9    November                 1586760
# 10    October                 1571285
# 11  September                  872741

# %%
fig1, ax1 = plt.subplots(figsize=(15, 15))
ax1.set_xlim([1,12])
ax1.set_ylim([0,5000000])
ax1.plot(rs_2016_u['Month'],rs_2016_u['Total_Dispatched_Trips'], label='UBER')
ax1.plot(rs_2016_v['Month'],rs_2016_v['Total_Dispatched_Trips'], label='VIA')
ax1.plot(rs_2016_l['Month'],rs_2016_l['Total_Dispatched_Trips'], label='LYFT')
ax1.plot(by_month_2016['Month_Name'], by_month_2016['Total_Dispatched_Trips'], label='Other')
ax1.xaxis.set_ticks(np.arange(1, 13, 1))
ax1.yaxis.set_ticks(np.arange(250000,9000000, 250000))
ax1.legend( ('UBER', 'VIA','LYFT','OTHER'), loc='upper left', shadow=True)
#ax1.ticklabel_format(style='plain') 
ax1.set_title('Dispatched Rides in 2016', 
             fontsize = 14)
ax1.set_xlabel('Month')
ax1.set_ylabel('Dispatched Rides')
# Out:
# Text(0, 0.5, 'Dispatched Rides')

# %%
fig2, ax2 = plt.subplots(figsize=(15, 15))
ax2.set_xlim([1,12])
ax2.set_ylim([0,5000000])
ax2.plot(rs_2017_u['Month'],rs_2017_u['Total_Dispatched_Trips'], label='UBER')
ax2.plot(rs_2017_v['Month'],rs_2017_v['Total_Dispatched_Trips'], label='VIA')
ax2.plot(rs_2017_l['Month'],rs_2017_l['Total_Dispatched_Trips'], label='LYFT')
ax2.plot(by_month_2017['Month_Name'], by_month_2017['Total_Dispatched_Trips'], label='Other')
ax2.xaxis.set_ticks(np.arange(1, 13, 1))
ax2.yaxis.set_ticks(np.arange(500000,13000000, 300000))
ax2.legend( ('UBER', 'VIA','LYFT','OTHER'), loc='upper left', shadow=True)
#ax2.ticklabel_format(style='plain') 
ax2.set_title('Dispatched Rides in 2017', 
             fontsize = 14)
ax2.set_xlabel('Month')
ax2.set_ylabel('Dispatched Rides')
# Out:
# Text(0, 0.5, 'Dispatched Rides')

# %%
fig3, ax3 = plt.subplots(figsize=(15, 15))
ax3.set_xlim([1,12])
ax3.set_ylim([0,5000000])
ax3.plot(rs_2018_u['Month'],rs_2018_u['Total_Dispatched_Trips'], label='UBER')
ax3.plot(rs_2018_v['Month'],rs_2018_v['Total_Dispatched_Trips'], label='VIA')
ax3.plot(rs_2018_l['Month'],rs_2018_l['Total_Dispatched_Trips'], label='LYFT')
ax3.plot(by_month_2018['Month_Name'], by_month_2018['Total_Dispatched_Trips'], label='Other')
ax3.xaxis.set_ticks(np.arange(1, 13, 1))
ax3.yaxis.set_ticks(np.arange(700000,16000000, 300000))
ax3.legend( ('UBER', 'VIA','LYFT','OTHER'), loc='upper left', shadow=True)
#ax3.ticklabel_format(style='plain') 
ax3.set_title('Dispatched Rides in 2018', 
             fontsize = 14)
ax3.set_xlabel('Month')
ax3.set_ylabel('Dispatched Rides')
# Out:
# Text(0, 0.5, 'Dispatched Rides')

# %%
print(rs_2019_u['Month_Name'])
fig4, ax4 = plt.subplots(figsize=(15, 15))
ax4.set_xlim([1,12])
ax4.set_ylim([0,5000000])
ax4.plot(rs_2019_u['Month'],rs_2019_u['Total_Dispatched_Trips'], label='UBER')
ax4.plot(rs_2019_v['Month'],rs_2019_v['Total_Dispatched_Trips'], label='VIA')
ax4.plot(rs_2019_l['Month'],rs_2019_l['Total_Dispatched_Trips'], label='LYFT')
ax4.plot(by_month_2019['Month_Name'], by_month_2019['Total_Dispatched_Trips'], label='Other')
ax4.xaxis.set_ticks(np.arange(1, 13, 1))
ax4.yaxis.set_ticks(np.arange(700000,18000000, 300000))
ax4.legend( ('UBER', 'VIA','LYFT','OTHER'), loc='upper left', shadow=True)
#ax4.ticklabel_format(style='plain') 
ax4.set_title('Dispatched Rides in 2019', 
             fontsize = 14)
ax4.set_xlabel('Month')
ax4.set_ylabel('Dispatched Rides')
# Out:
# 2024       January
# 4948      February
# 8495         March
# 11988        April
# 14915          May
# 17782         June
# 20732         July
# 23934       August
# 26907    September
# 29792      October
# 32862     November
# 36218     December
# Name: Month_Name, dtype: object
# Text(0, 0.5, 'Dispatched Rides')

# %%
fig5, ax5 = plt.subplots(figsize=(15, 15))
ax5.set_xlim([1,12])
ax5.set_ylim([0,5000000])
ax5.plot(rs_2020_u['Month'],rs_2020_u['Total_Dispatched_Trips'], label='UBER')
ax5.plot(rs_2020_v['Month'],rs_2020_v['Total_Dispatched_Trips'], label='VIA')
ax5.plot(rs_2020_l['Month'],rs_2020_l['Total_Dispatched_Trips'], label='LYFT')
ax5.plot(by_month_2015['Month_Name'], by_month_2015['Total_Dispatched_Trips'], label='Other')
ax5.xaxis.set_ticks(np.arange(1, 13, 1))
ax5.yaxis.set_ticks(np.arange(0,17500000, 300000))
ax5.legend( ('UBER', 'VIA','LYFT','OTHER'), loc='upper left', shadow=True)
#ax5.ticklabel_format(style='plain') 
ax5.set_title('Dispatched Rides in 2020', 
             fontsize = 14)
ax5.set_xlabel('Month')
ax5.set_ylabel('Dispatched Rides')
# Out:
# Text(0, 0.5, 'Dispatched Rides')

# %%
# Out:
#         Month  Percentage_Change_for_UBER Percentage_Change_for_VIA  \
# 0     January                  129.881432
# 1    February                  121.609876
# 2       March                  119.056371
# 3       April                  123.816137                   292.496
# 4         May                  190.715758                   283.709
# 5        June                   90.236145                   223.476
# 6        July                   89.828959                   194.635
# 7      August                   77.713266                   177.156
# 8   September                   74.744653                   170.352
# 9     October                   60.729894                    150.87
# 10   November                   66.882952                    134.35
# 11   December                   81.418624                   146.712
#
#    Percentage_Change_for_LYFT  Percentage_Change_for_OTHER
# 0                                               189.365662
# ...

# %%
yearly_change_df1 = pd.DataFrame()
yearly_change_df1['Month'] = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
change_v = {}
change_l = {}
change_o = {}

for month in rs_2016_u['Month_Name']:
    value_2016 = rs_2016_u[rs_2016_u['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2017 = rs_2017_u[rs_2017_u['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_u[month] = ((value_2017.values[0][0] - value_2016.values[0][0])/value_2016.values[0][0])* 100
    
for month in rs_2016_v['Month_Name']:
    value_2016 = rs_2016_v[rs_2016_v['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2017 = rs_2017_v[rs_2017_v['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_v[month] = ((value_2017.values[0][0] - value_2016.values[0][0])/value_2016.values[0][0])* 100
    
for month in rs_2016_l['Month_Name']:
    value_2016 = rs_2016_l[rs_2016_l['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2017 = rs_2017_l[rs_2017_l['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_l[month] = ((value_2017.values[0][0] - value_2016.values[0][0])/value_2016.values[0][0])* 100
    
for month in by_month_2017['Month_Name']:
    value_2017 = by_month_2017[by_month_2017['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2016 = by_month_2016[by_month_2016['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_o[month] = ((value_2017.values[0][0] - value_2016.values[0][0])/value_2016.values[0][0])* 100


month_dict = {1: 'January', 2:'February', 3: 'March', 4: ' April', 5: 'May', 6: 'June', 7: 'July', 8: 'August', 9:'September', 10: 'October', 11: 'November', 12: 'December'}
yearly_change_df1['Percentage_Change_for_UBER'] = yearly_change_df1['Month'].apply(lambda x: change_u.get(x)).fillna('')
yearly_change_df1['Percentage_Change_for_VIA'] = yearly_change_df1['Month'].apply(lambda x: change_v.get(x)).fillna('')
yearly_change_df1['Percentage_Change_for_LYFT'] = yearly_change_df1['Month'].apply(lambda x: change_l.get(x)).fillna('')
yearly_change_df1['Percentage_Change_for_OTHER'] = yearly_change_df1['Month'].apply(lambda x: change_o.get(x)).fillna('')

print(by_month_2015)
print(yearly_change_df1)
# Out:
#    Month_Name  Total_Dispatched_Trips
# 0       April                  716394
# 1      August                  548911
# 2    December                 1678867
# 3    February                  445020
# 4     January                  515876
# 5        July                  410502
# 6        June                  611583
# 7       March                  495068
# 8         May                  593071
# 9    November                 1586760
# 10    October                 1571285
# 11  September                  872741
#         Month  Percentage_Change_for_UBER  Percentage_Change_for_VIA  \
# 0     January                   79.876636                 135.373891
# 1    February                   50.072701                  79.715691
# 2       March                   74.589347                  69.530137
# 3       April                   60.301374                  67.841152
# 4         May                   63.110022                  83.756872
# ...

# %%
yearly_change_df2 = pd.DataFrame()
yearly_change_df2['Month'] = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
change_v = {}
change_l = {}
change_o = {}

for month in rs_2017_u['Month_Name']:
    value_2017 = rs_2017_u[rs_2017_u['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2018 = rs_2018_u[rs_2018_u['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_u[month] = ((value_2018.values[0][0] - value_2017.values[0][0])/value_2017.values[0][0])* 100
    
for month in rs_2017_v['Month_Name']:
    value_2017 = rs_2017_v[rs_2017_v['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2018 = rs_2018_v[rs_2018_v['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_v[month] = ((value_2018.values[0][0] - value_2017.values[0][0])/value_2017.values[0][0])* 100
    
for month in rs_2017_l['Month_Name']:
    value_2017 = rs_2017_l[rs_2017_l['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2018 = rs_2018_l[rs_2018_l['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_l[month] = ((value_2018.values[0][0] - value_2017.values[0][0])/value_2017.values[0][0])* 100
    
for month in by_month_2017['Month_Name']:
    value_2017 = by_month_2017[by_month_2017['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2018 = by_month_2018[by_month_2018['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_o[month] = ((value_2018.values[0][0] - value_2017.values[0][0])/value_2017.values[0][0])* 100


month_dict = {1: 'January', 2:'February', 3: 'March', 4: ' April', 5: 'May', 6: 'June', 7: 'July', 8: 'August', 9:'September', 10: 'October', 11: 'November', 12: 'December'}
yearly_change_df2['Percentage_Change_for_UBER'] = yearly_change_df2['Month'].apply(lambda x: change_u.get(x)).fillna('')
yearly_change_df2['Percentage_Change_for_VIA'] = yearly_change_df2['Month'].apply(lambda x: change_v.get(x)).fillna('')
yearly_change_df2['Percentage_Change_for_LYFT'] = yearly_change_df2['Month'].apply(lambda x: change_l.get(x)).fillna('')
yearly_change_df2['Percentage_Change_for_OTHER'] = yearly_change_df2['Month'].apply(lambda x: change_o.get(x)).fillna('')


print(yearly_change_df2)
# Out:
#         Month  Percentage_Change_for_UBER  Percentage_Change_for_VIA  \
# 0     January                   50.857424                  41.372186
# 1    February                   58.828455                  43.039716
# 2       March                   55.780155                  41.062322
# 3       April                   61.616746                  33.760202
# 4         May                   54.411176                  18.407692
# 5        June                   49.105051                  -5.392313
# 6        July                   56.917046                  -5.724192
# 7      August                   56.356257                 -10.702065
# 8   September                   47.502375                   1.478968
# 9     October                   44.682380                   1.989912
# 10   November                   36.113367                  -1.249203
# 11   December                   26.726995                  -8.797117
#
#     Percentage_Change_for_LYFT  Percentage_Change_for_OTHER
# ...

# %%
yearly_change_df3 = pd.DataFrame()
yearly_change_df3['Month'] = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
change_v = {}
change_l = {}
change_o = {}

for month in rs_2018_u['Month_Name']:
    value_2019 = rs_2019_u[rs_2019_u['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2018 = rs_2018_u[rs_2018_u['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_u[month] = ((value_2019.values[0][0] - value_2018.values[0][0])/value_2018.values[0][0])* 100
    
for month in rs_2018_v['Month_Name']:
    value_2019 = rs_2019_v[rs_2019_v['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2018 = rs_2018_v[rs_2018_v['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_v[month] = ((value_2019.values[0][0] - value_2018.values[0][0])/value_2018.values[0][0])* 100
    
for month in rs_2018_l['Month_Name']:
    value_2019 = rs_2019_l[rs_2019_l['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2018 = rs_2018_l[rs_2018_l['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_l[month] = ((value_2019.values[0][0] - value_2018.values[0][0])/value_2018.values[0][0])* 100
    
for month in by_month_2018['Month_Name']:
    value_2018 = by_month_2018[by_month_2018['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2019 = by_month_2019[by_month_2019['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_o[month] = ((value_2019.values[0][0] - value_2018.values[0][0])/value_2018.values[0][0])* 100


month_dict = {1: 'January', 2:'February', 3: 'March', 4: ' April', 5: 'May', 6: 'June', 7: 'July', 8: 'August', 9:'September', 10: 'October', 11: 'November', 12: 'December'}
yearly_change_df3['Percentage_Change_for_UBER'] = yearly_change_df3['Month'].apply(lambda x: change_u.get(x)).fillna('')
yearly_change_df3['Percentage_Change_for_VIA'] = yearly_change_df3['Month'].apply(lambda x: change_v.get(x)).fillna('')
yearly_change_df3['Percentage_Change_for_LYFT'] = yearly_change_df3['Month'].apply(lambda x: change_l.get(x)).fillna('')
yearly_change_df3['Percentage_Change_for_OTHER'] = yearly_change_df3['Month'].apply(lambda x: change_o.get(x)).fillna('')


print(yearly_change_df3)
# Out:
#         Month  Percentage_Change_for_UBER  Percentage_Change_for_VIA  \
# 0     January                   38.659997                  14.015917
# 1    February                   17.352896                   5.980256
# 2       March                   28.122704                   5.325750
# 3       April                   18.415162                   4.264497
# 4         May                   16.907742                   1.779746
# 5        June                    8.510484                  25.012055
# 6        July                   -0.144732                   7.868508
# 7      August                   -0.960011                   0.306955
# 8   September                   -0.606421                  -7.838139
# 9     October                   -1.050989                 -16.210039
# 10   November                    7.254885                 -19.039734
# 11   December                    7.371432                 -22.518832
#
#     Percentage_Change_for_LYFT  Percentage_Change_for_OTHER
# ...

# %%
yearly_change_df4 = pd.DataFrame()
yearly_change_df4['Month'] = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
change_v = {}
change_l = {}
change_o = {}

for month in rs_2019_u['Month_Name']:
    value_2019 = rs_2019_u[rs_2019_u['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2020 = rs_2020_u[rs_2020_u['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_u[month] = ((value_2020.values[0][0] - value_2019.values[0][0])/value_2019.values[0][0])* 100
    
for month in rs_2019_v['Month_Name']:
    value_2019 = rs_2019_v[rs_2019_v['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2020 = rs_2020_v[rs_2020_v['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_v[month] = ((value_2020.values[0][0] - value_2019.values[0][0])/value_2019.values[0][0])* 100
    
for month in rs_2019_l['Month_Name']:
    value_2019 = rs_2019_l[rs_2019_l['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2020 = rs_2020_l[rs_2020_l['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_l[month] = ((value_2020.values[0][0] - value_2019.values[0][0])/value_2019.values[0][0])* 100
    
for month in by_month_2019['Month_Name']:
    value_2019 = by_month_2019[by_month_2019['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2020 = by_month_2020[by_month_2020['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_o[month] = ((value_2020.values[0][0] - value_2019.values[0][0])/value_2019.values[0][0])* 100


month_dict = {1: 'January', 2:'February', 3: 'March', 4: ' April', 5: 'May', 6: 'June', 7: 'July', 8: 'August', 9:'September', 10: 'October', 11: 'November', 12: 'December'}
yearly_change_df4['Percentage_Change_for_UBER'] = yearly_change_df4['Month'].apply(lambda x: change_u.get(x)).fillna('')
yearly_change_df4['Percentage_Change_for_VIA'] = yearly_change_df4['Month'].apply(lambda x: change_v.get(x)).fillna('')
yearly_change_df4['Percentage_Change_for_LYFT'] = yearly_change_df4['Month'].apply(lambda x: change_l.get(x)).fillna('')
yearly_change_df4['Percentage_Change_for_OTHER'] = yearly_change_df4['Month'].apply(lambda x: change_o.get(x)).fillna('')


print(yearly_change_df4)
# Out:
#         Month  Percentage_Change_for_UBER  Percentage_Change_for_VIA  \
# 0     January                   -9.895836                 -38.532244
# 1    February                   16.593061                 -34.757187
# 2       March                  -42.968554                 -68.890474
# 3       April                  -80.182983                 -93.691965
# 4         May                  -72.541194                 -89.397590
# 5        June                  -64.475923                 -86.029573
# 6        July                  -49.572186                 -82.514313
# 7      August                  -43.585241                 -80.981428
# 8   September                  -36.645658                 -83.620270
# 9     October                  -32.475157                 -83.579331
# 10   November                  -46.349929                 -83.087043
# 11   December                  -47.307676                 -82.009427
#
#     Percentage_Change_for_LYFT  Percentage_Change_for_OTHER
# ...

# %%
df1 = pd.read_csv('201501-citibike-tripdata.csv')
df2 = pd.read_csv('201502-citibike-tripdata.csv')
df3 = pd.read_csv('201503-citibike-tripdata.csv')
df4 = pd.read_csv('201504-citibike-tripdata.csv')
df5 = pd.read_csv('201505-citibike-tripdata.csv')
df6 = pd.read_csv('201506-citibike-tripdata.csv')
df7 = pd.read_csv('201507-citibike-tripdata.csv')
df8 = pd.read_csv('201508-citibike-tripdata.csv')
df9 = pd.read_csv('201509-citibike-tripdata.csv')
df10 = pd.read_csv('201510-citibike-tripdata.csv')
df11 = pd.read_csv('201511-citibike-tripdata.csv')
df12 = pd.read_csv('201512-citibike-tripdata.csv')

print(df1)
print(df2)
# Out:
#         tripduration        starttime       stoptime  start station id  \
# 0               1346    1/1/2015 0:01  1/1/2015 0:24               455
# 1                363    1/1/2015 0:02  1/1/2015 0:08               434
# 2                346    1/1/2015 0:04  1/1/2015 0:10               491
# 3                182    1/1/2015 0:04  1/1/2015 0:07               384
# 4                969    1/1/2015 0:05  1/1/2015 0:21               474
# ...              ...              ...            ...               ...
# 285547           169  1/31/2015 23:57  2/1/2015 0:00               161
# 285548           827  1/31/2015 23:58  2/1/2015 0:12               252
# 285549           798  1/31/2015 23:58  2/1/2015 0:11               127
# 285550           725  1/31/2015 23:58  2/1/2015 0:10               435
# 285551           892  1/31/2015 23:59  2/1/2015 0:14               504
#
#                   start station name  start station latitude  \
# ...

# %%
df_bike = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12])
print(df_bike)
# Out:
#         tripduration            starttime             stoptime  \
# 0               1346        1/1/2015 0:01        1/1/2015 0:24
# 1                363        1/1/2015 0:02        1/1/2015 0:08
# 2                346        1/1/2015 0:04        1/1/2015 0:10
# 3                182        1/1/2015 0:04        1/1/2015 0:07
# 4                969        1/1/2015 0:05        1/1/2015 0:21
# ...              ...                  ...                  ...
# 804120           509  12/31/2015 16:50:17  12/31/2015 16:58:46
# 804121           591  12/31/2015 17:17:52  12/31/2015 17:27:43
# 804122           197  12/31/2015 17:56:22  12/31/2015 17:59:39
# 804123           372  12/31/2015 21:20:38  12/31/2015 21:26:50
# 804124           395  12/31/2015 21:49:19  12/31/2015 21:55:55
#
#         start station id          start station name  start station latitude  \
# 0                    455             1 Ave & E 44 St               40.750020
# ...

# %%
gender_counts = df_bike['gender'].value_counts()
sub_counts = df_bike['usertype'].value_counts()


bike_month_df_2015 = pd.DataFrame({'Month':['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'],'Trips':[len(df1.index),len(df2.index),len(df3.index),len(df4.index),len(df5.index),len(df6.index),len(df7.index),len(df8.index),len(df9.index),len(df10.index),len(df11.index),len(df12.index)]})
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
f = plt.figure(figsize=(15,15))

ax = f.add_subplot()

ax.set_ylim([0,5000000])
ax.plot(rs_2015_u['Month_Name'], rs_2015_u['Total_Dispatched_Trips'], label='UBER')
ax.plot(rs_2015_v['Month_Name'],rs_2015_v['Total_Dispatched_Trips'], label='VIA')
ax.plot(rs_2015_l['Month_Name'],rs_2015_l['Total_Dispatched_Trips'], label='LYFT')
ax.plot(rs_2015_u['Month_Name'], by_month_2015['Total_Dispatched_Trips'], label='Other')
ax.plot(bike_month_df_2015['Month'], bike_month_df_2015['Trips'])
#ax.plot(bike_month_df['Month'], bike_month_df['Trips'], label='Citi Bike')
ax.xaxis.set_ticks(month_order)
ax.yaxis.set_ticks(np.arange(0,5000000, 250000))
ax.legend( ('UBER', 'VIA','LYFT','OTHER', 'CITI BIKE'), loc='upper left', shadow=True)
#ax.ticklabel_format(style='plain') 
ax.set_title('Dispatched Rides in 2015', 
             fontsize = 14)
ax.set_xlabel('Month')
ax.set_ylabel('Dispatched Rides')
# Out:
# Text(0, 0.5, 'Dispatched Rides')

# %%
df11 = pd.read_csv('201601-citibike-tripdata.csv')
df21 = pd.read_csv('201602-citibike-tripdata.csv')
df31 = pd.read_csv('201603-citibike-tripdata.csv')
df41 = pd.read_csv('201604-citibike-tripdata.csv')
df51 = pd.read_csv('201605-citibike-tripdata.csv')
df61 = pd.read_csv('201606-citibike-tripdata.csv')
df71 = pd.read_csv('201607-citibike-tripdata.csv')
df81 = pd.read_csv('201608-citibike-tripdata.csv')
df91 = pd.read_csv('201609-citibike-tripdata.csv')
df101 = pd.read_csv('201610-citibike-tripdata.csv')
df111 = pd.read_csv('201611-citibike-tripdata.csv')
df121 = pd.read_csv('201612-citibike-tripdata.csv')

# %%
df_bike1 = pd.concat([df11, df21, df31, df41, df51, df61, df71, df81, df91, df101, df111, df121])
print(df_bike)
# Out:
#         tripduration            starttime             stoptime  \
# 0               1346        1/1/2015 0:01        1/1/2015 0:24
# 1                363        1/1/2015 0:02        1/1/2015 0:08
# 2                346        1/1/2015 0:04        1/1/2015 0:10
# 3                182        1/1/2015 0:04        1/1/2015 0:07
# 4                969        1/1/2015 0:05        1/1/2015 0:21
# ...              ...                  ...                  ...
# 804120           509  12/31/2015 16:50:17  12/31/2015 16:58:46
# 804121           591  12/31/2015 17:17:52  12/31/2015 17:27:43
# 804122           197  12/31/2015 17:56:22  12/31/2015 17:59:39
# 804123           372  12/31/2015 21:20:38  12/31/2015 21:26:50
# 804124           395  12/31/2015 21:49:19  12/31/2015 21:55:55
#
#         start station id          start station name  start station latitude  \
# 0                    455             1 Ave & E 44 St               40.750020
# ...

# %%
gender_counts1 = df_bike1['gender'].value_counts()
sub_counts1 = df_bike1['usertype'].value_counts()


bike_month_df_2016 = pd.DataFrame({'Month':['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'],'Trips':[len(df11.index),len(df21.index),len(df31.index),len(df41.index),len(df51.index),len(df61.index),len(df71.index),len(df81.index),len(df91.index),len(df101.index),len(df111.index),len(df121.index)]})
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
f = plt.figure(figsize=(15,15))

ax = f.add_subplot()

ax.set_ylim([0,5000000])
ax.plot(rs_2016_u['Month_Name'], rs_2016_u['Total_Dispatched_Trips'], label='UBER')
ax.plot(rs_2016_v['Month_Name'],rs_2016_v['Total_Dispatched_Trips'], label='VIA')
ax.plot(rs_2016_l['Month_Name'],rs_2016_l['Total_Dispatched_Trips'], label='LYFT')
ax.plot(rs_2016_u['Month_Name'], by_month_2016['Total_Dispatched_Trips'], label='Other')
ax.plot(bike_month_df_2016['Month'], bike_month_df_2016['Trips'])
#ax.plot(bike_month_df['Month'], bike_month_df['Trips'], label='Citi Bike')
ax.xaxis.set_ticks(month_order)
ax.yaxis.set_ticks(np.arange(0,9000000, 250000))
ax.legend( ('UBER', 'VIA','LYFT','OTHER', 'CITI BIKE'), loc='upper left', shadow=True)
ax.ticklabel_format(axis="y", style="plain") 
ax.set_title('Dispatched Rides in 2016', 
             fontsize = 14)
ax.set_xlabel('Month')
ax.set_ylabel('Dispatched Rides')
# Out:
# Text(0, 0.5, 'Dispatched Rides')

# %%
df12 = pd.read_csv('D:/data/201701-citibike-tripdata.csv')
df22 = pd.read_csv('D:/data/201702-citibike-tripdata.csv')
df32 = pd.read_csv('D:/data/201703-citibike-tripdata.csv')
df42 = pd.read_csv('D:/data/201704-citibike-tripdata.csv')
df52 = pd.read_csv('D:/data/201705-citibike-tripdata.csv')
df62 = pd.read_csv('D:/data/201706-citibike-tripdata.csv')

# %%
df72 = pd.read_csv('D:/data/201707-citibike-tripdata.csv')
df82 = pd.read_csv('D:/data/201708-citibike-tripdata.csv')
df92 = pd.read_csv('D:/data/201709-citibike-tripdata.csv')
df102 = pd.read_csv('D:/data/201710-citibike-tripdata.csv')
df112 = pd.read_csv('D:/data/201711-citibike-tripdata.csv')
df122 = pd.read_csv('D:/data/201712-citibike-tripdata.csv')

# %%
df_bike2 = pd.concat([df12, df22, df32, df42, df52, df62, df72, df82, df92, df102, df112, df122])

# %%
gender_counts2 = df_bike2['gender'].value_counts()
sub_counts2 = df_bike2['usertype'].value_counts()


bike_month_df_2017 = pd.DataFrame({'Month':['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'],'Trips':[len(df122.index),len(df22.index),len(df32.index),len(df42.index),len(df52.index),len(df62.index),len(df72.index),len(df82.index),len(df92.index),len(df102.index),len(df112.index),len(df122.index)]})
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
f = plt.figure(figsize=(15,15))

ax = f.add_subplot()

ax.set_ylim([0,13000000])
ax.plot(rs_2017_u['Month_Name'], rs_2017_u['Total_Dispatched_Trips'], label='UBER')
ax.plot(rs_2017_v['Month_Name'],rs_2017_v['Total_Dispatched_Trips'], label='VIA')
ax.plot(rs_2017_l['Month_Name'],rs_2017_l['Total_Dispatched_Trips'], label='LYFT')
ax.plot(rs_2017_u['Month_Name'], by_month_2017['Total_Dispatched_Trips'], label='Other')
ax.plot(bike_month_df_2017['Month'], bike_month_df_2017['Trips'])
#ax.plot(bike_month_df['Month'], bike_month_df['Trips'], label='Citi Bike')
ax.xaxis.set_ticks(month_order)
ax.yaxis.set_ticks(np.arange(0,13000000, 250000))
ax.legend( ('UBER', 'VIA','LYFT','OTHER', 'CITI BIKE'), loc='upper left', shadow=True)
ax.ticklabel_format(axis="y", style="plain") 
ax.set_title('Dispatched Rides in 2017', 
             fontsize = 14)
ax.set_xlabel('Month')
ax.set_ylabel('Dispatched Rides')

# %%
df13 = pd.read_csv('D:/data/201801-citibike-tripdata.csv')
df23 = pd.read_csv('D:/data/201802-citibike-tripdata.csv')
df33 = pd.read_csv('D:/data/201803-citibike-tripdata.csv')
df43 = pd.read_csv('D:/data/201804-citibike-tripdata.csv')
df53 = pd.read_csv('D:/data/201805-citibike-tripdata.csv')
df63 = pd.read_csv('D:/data/201806-citibike-tripdata.csv')

# %%
df73 = pd.read_csv('D:/data/201807-citibike-tripdata.csv')
df83 = pd.read_csv('D:/data/201808-citibike-tripdata.csv')
df93 = pd.read_csv('D:/data/201809-citibike-tripdata.csv')
df103 = pd.read_csv('D:/data/201810-citibike-tripdata.csv')
df113 = pd.read_csv('D:/data/201811-citibike-tripdata.csv')
df123 = pd.read_csv('D:/data/201812-citibike-tripdata.csv')

# %%
df_bike3 = pd.concat([df13, df23, df33, df43, df53, df63, df73, df83, df82, df103, df113, df123])

# %%
gender_counts3 = df_bike3['gender'].value_counts()
sub_counts3 = df_bike3['usertype'].value_counts()


bike_month_df_2018 = pd.DataFrame({'Month':['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'],'Trips':[len(df13.index),len(df23.index),len(df33.index),len(df43.index),len(df53.index),len(df63.index),len(df73.index),len(df83.index),len(df93.index),len(df103.index),len(df113.index),len(df123.index)]})
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
f = plt.figure(figsize=(15,15))

ax = f.add_subplot()

ax.set_ylim([0,13000000])
ax.plot(rs_2018_u['Month_Name'], rs_2018_u['Total_Dispatched_Trips'], label='UBER')
ax.plot(rs_2018_v['Month_Name'],rs_2018_v['Total_Dispatched_Trips'], label='VIA')
ax.plot(rs_2018_l['Month_Name'],rs_2018_l['Total_Dispatched_Trips'], label='LYFT')
ax.plot(rs_2018_u['Month_Name'], by_month_2018['Total_Dispatched_Trips'], label='Other')
ax.plot(bike_month_df_2018['Month'], bike_month_df_2018['Trips'])
#ax.plot(bike_month_df['Month'], bike_month_df['Trips'], label='Citi Bike')
ax.xaxis.set_ticks(month_order)
ax.yaxis.set_ticks(np.arange(0,16000000, 250000))
ax.legend( ('UBER', 'VIA','LYFT','OTHER', 'CITI BIKE'), loc='upper left', shadow=True)
ax.ticklabel_format(axis="y", style="plain") 
ax.set_title('Dispatched Rides in 2018', 
             fontsize = 14)
ax.set_xlabel('Month')
ax.set_ylabel('Dispatched Rides')
# Out:
# Text(0, 0.5, 'Dispatched Rides')

# %%
df14 = pd.read_csv('D:/data/201901-citibike-tripdata.csv')
df24 = pd.read_csv('D:/data/201902-citibike-tripdata.csv')
df34 = pd.read_csv('D:/data/201903-citibike-tripdata.csv')
df44 = pd.read_csv('D:/data/201904-citibike-tripdata.csv')
df54 = pd.read_csv('D:/data/201905-citibike-tripdata.csv')
df64 = pd.read_csv('D:/data/201906-citibike-tripdata.csv')

# %%
df74 = pd.read_csv('D:/data/201907-citibike-tripdata.csv')
df84 = pd.read_csv('D:/data/201908-citibike-tripdata.csv')
df94 = pd.read_csv('D:/data/201909-citibike-tripdata.csv')
df104 = pd.read_csv('D:/data/201910-citibike-tripdata.csv')
df114 = pd.read_csv('D:/data/201911-citibike-tripdata.csv')
df124 = pd.read_csv('D:/data/201912-citibike-tripdata.csv')

# %%
df_bike4 = pd.concat([df14, df24, df34, df44, df54, df64, df74, df84, df94, df104, df114, df124])

# %%
gender_counts4 = df_bike4['gender'].value_counts()
sub_counts4 = df_bike4['usertype'].value_counts()


bike_month_df_2019 = pd.DataFrame({'Month':['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'],'Trips':[len(df14.index),len(df24.index),len(df34.index),len(df44.index),len(df54.index),len(df64.index),len(df74.index),len(df84.index),len(df94.index),len(df104.index),len(df114.index),len(df124.index)]})
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
f = plt.figure(figsize=(15,15))

ax = f.add_subplot()

ax.set_ylim([0,13000000])
ax.plot(rs_2019_u['Month_Name'], rs_2019_u['Total_Dispatched_Trips'], label='UBER')
ax.plot(rs_2019_v['Month_Name'],rs_2019_v['Total_Dispatched_Trips'], label='VIA')
ax.plot(rs_2019_l['Month_Name'],rs_2019_l['Total_Dispatched_Trips'], label='LYFT')
ax.plot(rs_2019_u['Month_Name'], by_month_2018['Total_Dispatched_Trips'], label='Other')
ax.plot(bike_month_df_2019['Month'], bike_month_df_2019['Trips'])
#ax.plot(bike_month_df['Month'], bike_month_df['Trips'], label='Citi Bike')
ax.xaxis.set_ticks(month_order)
ax.yaxis.set_ticks(np.arange(0,16000000, 250000))
ax.legend( ('UBER', 'VIA','LYFT','OTHER', 'CITI BIKE'), loc='upper left', shadow=True)
ax.ticklabel_format(axis="y", style="plain") 
ax.set_title('Dispatched Rides in 2019', 
             fontsize = 14)
ax.set_xlabel('Month')
ax.set_ylabel('Dispatched Rides')

# %%
df15 = pd.read_csv('D:/data/202001-citibike-tripdata.csv')
df25 = pd.read_csv('D:/data/202002-citibike-tripdata.csv')
df35 = pd.read_csv('D:/data/202003-citibike-tripdata.csv')
df45 = pd.read_csv('D:/data/202004-citibike-tripdata.csv')
df55 = pd.read_csv('D:/data/202005-citibike-tripdata.csv')
df65 = pd.read_csv('D:/data/202006-citibike-tripdata.csv')

# %%
df75 = pd.read_csv('D:/data/202007-citibike-tripdata.csv')
df85 = pd.read_csv('D:/data/202008-citibike-tripdata.csv')
df95 = pd.read_csv('D:/data/202009-citibike-tripdata.csv')
df105 = pd.read_csv('D:/data/202010-citibike-tripdata.csv')
df115 = pd.read_csv('D:/data/202011-citibike-tripdata.csv')
df125 = pd.read_csv('D:/data/202012-citibike-tripdata.csv')

# %%
df_bike5 = pd.concat([df15, df25, df35, df45, df55, df65, df75, df85, df95, df105, df115, df125])

# %%
gender_counts5 = df_bike5['gender'].value_counts()
sub_counts5 = df_bike5['usertype'].value_counts()


bike_month_df_2020 = pd.DataFrame({'Month':['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'],'Trips':[len(df15.index),len(df25.index),len(df35.index),len(df45.index),len(df55.index),len(df65.index),len(df75.index),len(df85.index),len(df94.index),len(df104.index),len(df114.index),len(df124.index)]})
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
f = plt.figure(figsize=(15,15))

ax = f.add_subplot()

ax.set_ylim([0,13000000])
ax.plot(rs_2019_u['Month_Name'], rs_2019_u['Total_Dispatched_Trips'], label='UBER')
ax.plot(rs_2019_v['Month_Name'],rs_2019_v['Total_Dispatched_Trips'], label='VIA')
ax.plot(rs_2019_l['Month_Name'],rs_2019_l['Total_Dispatched_Trips'], label='LYFT')
ax.plot(rs_2019_u['Month_Name'], by_month_2018['Total_Dispatched_Trips'], label='Other')
ax.plot(bike_month_df_2019['Month'], bike_month_df_2019['Trips'])
#ax.plot(bike_month_df['Month'], bike_month_df['Trips'], label='Citi Bike')
ax.xaxis.set_ticks(month_order)
ax.yaxis.set_ticks(np.arange(0,16000000, 250000))
ax.legend( ('UBER', 'VIA','LYFT','OTHER', 'CITI BIKE'), loc='upper left', shadow=True)
ax.ticklabel_format(axis="y", style="plain") 
ax.set_title('Dispatched Rides in 2019', 
             fontsize = 14)
ax.set_xlabel('Month')
ax.set_ylabel('Dispatched Rides')

# %%
#di = {1:'Male', 2: 'Female', 0:'Unknown'}
#gender_counts.replace({"gender": di})
gender_counts1 = pd.DataFrame({'Count':[gender_counts.values[0],gender_counts.values[1],gender_counts.values[2]]},index=['Male', 'Female', 'Unknown'])
#plot = gender_counts1.plot(y='Counts', kind='pie',title = 'Gender of Users' ,startangle=90, autopct='%1.1f%%')

sub_counts1 = pd.DataFrame({'Count':[sub_counts.values[0], sub_counts.values[1]]}, index = ['Subscriber', 'Customer'])
fig, axs = plt.subplots(1, 2,figsize=(15,15))
axs[0].pie(sub_counts1['Count'] , startangle=90, autopct='%1.1f%%', labels = sub_counts1.index)
axs[1].pie(gender_counts1['Count'] , startangle=90, autopct='%1.1f%%',labels = gender_counts1.index)
axs[0].set_title('User Type')
axs[1].set_title('Gender')

# %%
average_usage_time = df_bike['tripduration']
plt.hist(df_bike['tripduration'], bins=2)

# %%
#di = {1:'Male', 2: 'Female', 0:'Unknown'}
#gender_counts.replace({"gender": di})
gender_counts1 = pd.DataFrame({'Count':[gender_counts.values[0],gender_counts.values[1],gender_counts.values[2]]},index=['Male', 'Female', 'Unknown'])
#plot = gender_counts1.plot(y='Counts', kind='pie',title = 'Gender of Users' ,startangle=90, autopct='%1.1f%%')

sub_counts1 = pd.DataFrame({'Count':[sub_counts.values[0], sub_counts.values[1]]}, index = ['Subscriber', 'Customer'])
fig, axs = plt.subplots(1, 2,figsize=(15,15))
axs[0].pie(sub_counts1['Count'] , startangle=90, autopct='%1.1f%%', labels = sub_counts1.index)
axs[1].pie(gender_counts1['Count'] , startangle=90, autopct='%1.1f%%',labels = gender_counts1.index)
axs[0].set_title('User Type')
axs[1].set_title('Gender')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e2cf99cda6e1> in <module>
#       1 #di = {1:'Male', 2: 'Female', 0:'Unknown'}
#       2 #gender_counts.replace({"gender": di})
# ----> 3 gender_counts1 = pd.DataFrame({'Count':[gender_counts.values[0],gender_counts.values[1],gender_counts.values[2]]},index=['Male', 'Female', 'Unknown'])
#       4 #plot = gender_counts1.plot(y='Counts', kind='pie',title = 'Gender of Users' ,startangle=90, autopct='%1.1f%%')
#       5
#
# NameError: name 'gender_counts' is not defined

# %%
#di = {1:'Male', 2: 'Female', 0:'Unknown'}
#gender_counts.replace({"gender": di})
gender_counts1 = pd.DataFrame({'Count':[gender_counts.values[0],gender_counts.values[1],gender_counts.values[2]]},index=['Male', 'Female', 'Unknown'])
#plot = gender_counts1.plot(y='Counts', kind='pie',title = 'Gender of Users' ,startangle=90, autopct='%1.1f%%')

sub_counts1 = pd.DataFrame({'Count':[sub_counts.values[0], sub_counts.values[1]]}, index = ['Subscriber', 'Customer'])
fig, axs = plt.subplots(1, 2,figsize=(15,15))
axs[0].pie(sub_counts1['Count'] , startangle=90, autopct='%1.1f%%', labels = sub_counts1.index)
axs[1].pie(gender_counts1['Count'] , startangle=90, autopct='%1.1f%%',labels = gender_counts1.index)
axs[0].set_title('User Type')
axs[1].set_title('Gender')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e2cf99cda6e1> in <module>
#       1 #di = {1:'Male', 2: 'Female', 0:'Unknown'}
#       2 #gender_counts.replace({"gender": di})
# ----> 3 gender_counts1 = pd.DataFrame({'Count':[gender_counts.values[0],gender_counts.values[1],gender_counts.values[2]]},index=['Male', 'Female', 'Unknown'])
#       4 #plot = gender_counts1.plot(y='Counts', kind='pie',title = 'Gender of Users' ,startangle=90, autopct='%1.1f%%')
#       5
#
# NameError: name 'gender_counts' is not defined

# %%
#di = {1:'Male', 2: 'Female', 0:'Unknown'}
#gender_counts.replace({"gender": di})
gender_counts1 = pd.DataFrame({'Count':[gender_counts.values[0],gender_counts.values[1],gender_counts.values[2]]},index=['Male', 'Female', 'Unknown'])
#plot = gender_counts1.plot(y='Counts', kind='pie',title = 'Gender of Users' ,startangle=90, autopct='%1.1f%%')

sub_counts1 = pd.DataFrame({'Count':[sub_counts.values[0], sub_counts.values[1]]}, index = ['Subscriber', 'Customer'])
fig, axs = plt.subplots(1, 2,figsize=(15,15))
axs[0].pie(sub_counts1['Count'] , startangle=90, autopct='%1.1f%%', labels = sub_counts1.index)
axs[1].pie(gender_counts1['Count'] , startangle=90, autopct='%1.1f%%',labels = gender_counts1.index)
axs[0].set_title('User Type')
axs[1].set_title('Gender')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e2cf99cda6e1> in <module>
#       1 #di = {1:'Male', 2: 'Female', 0:'Unknown'}
#       2 #gender_counts.replace({"gender": di})
# ----> 3 gender_counts1 = pd.DataFrame({'Count':[gender_counts.values[0],gender_counts.values[1],gender_counts.values[2]]},index=['Male', 'Female', 'Unknown'])
#       4 #plot = gender_counts1.plot(y='Counts', kind='pie',title = 'Gender of Users' ,startangle=90, autopct='%1.1f%%')
#       5
#
# NameError: name 'gender_counts' is not defined

# %%
#di = {1:'Male', 2: 'Female', 0:'Unknown'}
#gender_counts.replace({"gender": di})
gender_counts1 = pd.DataFrame({'Count':[gender_counts.values[0],gender_counts.values[1],gender_counts.values[2]]},index=['Male', 'Female', 'Unknown'])
#plot = gender_counts1.plot(y='Counts', kind='pie',title = 'Gender of Users' ,startangle=90, autopct='%1.1f%%')

sub_counts1 = pd.DataFrame({'Count':[sub_counts.values[0], sub_counts.values[1]]}, index = ['Subscriber', 'Customer'])
fig, axs = plt.subplots(1, 2,figsize=(15,15))
axs[0].pie(sub_counts1['Count'] , startangle=90, autopct='%1.1f%%', labels = sub_counts1.index)
axs[1].pie(gender_counts1['Count'] , startangle=90, autopct='%1.1f%%',labels = gender_counts1.index)
axs[0].set_title('User Type')
axs[1].set_title('Gender')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e2cf99cda6e1> in <module>
#       1 #di = {1:'Male', 2: 'Female', 0:'Unknown'}
#       2 #gender_counts.replace({"gender": di})
# ----> 3 gender_counts1 = pd.DataFrame({'Count':[gender_counts.values[0],gender_counts.values[1],gender_counts.values[2]]},index=['Male', 'Female', 'Unknown'])
#       4 #plot = gender_counts1.plot(y='Counts', kind='pie',title = 'Gender of Users' ,startangle=90, autopct='%1.1f%%')
#       5
#
# NameError: name 'gender_counts' is not defined

# %%
#di = {1:'Male', 2: 'Female', 0:'Unknown'}
#gender_counts.replace({"gender": di})
gender_counts1 = pd.DataFrame({'Count':[gender_counts.values[0],gender_counts.values[1],gender_counts.values[2]]},index=['Male', 'Female', 'Unknown'])
#plot = gender_counts1.plot(y='Counts', kind='pie',title = 'Gender of Users' ,startangle=90, autopct='%1.1f%%')

sub_counts1 = pd.DataFrame({'Count':[sub_counts.values[0], sub_counts.values[1]]}, index = ['Subscriber', 'Customer'])
fig, axs = plt.subplots(1, 2,figsize=(15,15))
axs[0].pie(sub_counts1['Count'] , startangle=90, autopct='%1.1f%%', labels = sub_counts1.index)
axs[1].pie(gender_counts1['Count'] , startangle=90, autopct='%1.1f%%',labels = gender_counts1.index)
axs[0].set_title('User Type')
axs[1].set_title('Gender')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e2cf99cda6e1> in <module>
#       1 #di = {1:'Male', 2: 'Female', 0:'Unknown'}
#       2 #gender_counts.replace({"gender": di})
# ----> 3 gender_counts1 = pd.DataFrame({'Count':[gender_counts.values[0],gender_counts.values[1],gender_counts.values[2]]},index=['Male', 'Female', 'Unknown'])
#       4 #plot = gender_counts1.plot(y='Counts', kind='pie',title = 'Gender of Users' ,startangle=90, autopct='%1.1f%%')
#       5
#
# NameError: name 'gender_counts' is not defined

# %%
yearly_change_df = pd.DataFrame()
yearly_change_df['Month'] = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
change_u = {}
change_v = {}
change_l = {}
change_o = {}
change_b = {}


for month in rs_2015_u['Month_Name']:
    value_2015 = rs_2015_u[rs_2015_u['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2016 = rs_2016_u[rs_2016_u['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_u[month] = ((value_2016.values[0][0] - value_2015.values[0][0])/value_2015.values[0][0])* 100
    
for month in rs_2015_v['Month_Name']:
    value_2015 = rs_2015_v[rs_2015_v['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2016 = rs_2016_v[rs_2016_v['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_v[month] = ((value_2016.values[0][0] - value_2015.values[0][0])/value_2015.values[0][0])* 100
    
for month in rs_2015_l['Month_Name']:
    value_2015 = rs_2015_l[rs_2015_l['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2016 = rs_2016_l[rs_2016_l['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_l[month] = ((value_2016.values[0][0] - value_2015.values[0][0])/value_2015.values[0][0])* 100
    
for month in by_month_2015['Month_Name']:
    value_2015 = by_month_2015[by_month_2015['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    value_2016 = by_month_2016[by_month_2016['Month_Name'] == month][['Total_Dispatched_Trips', 'Month_Name']]
    change_o[month] = ((value_2016.values[0][0] - value_2015.values[0][0])/value_2015.values[0][0])* 100
    
for month in bike_month_df_2015['Month']:
    value_2015 = bike_month_df_2015[bike_month_df_2015['Month'] == month][['Trips', 'Month']]
    value_2016 = bike_month_df_2016[bike_month_df_2016['Month'] == month][['Trips', 'Month']]

    change_b[month] = ((value_2016.values[0][0] - value_2015.values[0][0])/value_2015.values[0][0])* 100    


month_dict = {1: 'January', 2:'February', 3: 'March', 4: ' April', 5: 'May', 6: 'June', 7: 'July', 8: 'August', 9:'September', 10: 'October', 11: 'November', 12: 'December'}
yearly_change_df['Percentage_Change_for_UBER'] = yearly_change_df['Month'].apply(lambda x: change_u.get(x)).fillna('')
yearly_change_df['Percentage_Change_for_VIA'] = yearly_change_df['Month'].apply(lambda x: change_v.get(x)).fillna('')
yearly_change_df['Percentage_Change_for_LYFT'] = yearly_change_df['Month'].apply(lambda x: change_l.get(x)).fillna('')
yearly_change_df['Percentage_Change_for_OTHER'] = yearly_change_df['Month'].apply(lambda x: change_o.get(x)).fillna('')
yearly_change_df['Percentage_Change_for_CITI_BIKE'] = yearly_change_df['Month'].apply(lambda x: change_b.get(x)).fillna('')

#yearly_change_df['Percentage_Change_for_OTHER'] = change_o
    
print(yearly_change_df)
# Out:
#         Month  Percentage_Change_for_UBER Percentage_Change_for_VIA  \
# 0     January                  129.881432
# 1    February                  121.609876
# 2       March                  119.056371
# 3       April                  123.816137                   292.496
# 4         May                  190.715758                   283.709
# 5        June                   90.236145                   223.476
# 6        July                   89.828959                   194.635
# 7      August                   77.713266                   177.156
# 8   September                   74.744653                   170.352
# 9     October                   60.729894                    150.87
# 10   November                   66.882952                    134.35
# 11   December                   81.418624                   146.712
#
#    Percentage_Change_for_LYFT  Percentage_Change_for_OTHER  \
# 0                                               189.365662
# ...
